# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import os
from PIL import Image
import random
import h5py
import torch
import torch.nn as nn
import torchvision
import io
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Explanatory Data Analysis

# %%
DATA_PATH = Path(r"C:\Users\tomti\Desktop\Data Science stuffs\Project Skin cancer")

# %%
train_metadata_df = pd.read_csv(DATA_PATH / "train-metadata.csv")
train_metadata_df
# Out:
#              isic_id  target  patient_id  age_approx     sex  \
# 0       ISIC_0015670       0  IP_1235828        60.0    male
# 1       ISIC_0015845       0  IP_8170065        60.0    male
# 2       ISIC_0015864       0  IP_6724798        60.0    male
# 3       ISIC_0015902       0  IP_4111386        65.0    male
# 4       ISIC_0024200       0  IP_8313778        55.0    male
# ...              ...     ...         ...         ...     ...
# 401054  ISIC_9999937       0  IP_1140263        70.0    male
# 401055  ISIC_9999951       0  IP_5678181        60.0    male
# 401056  ISIC_9999960       0  IP_0076153        65.0  female
# 401057  ISIC_9999964       0  IP_5231513        30.0  female
# 401058  ISIC_9999967       0  IP_6426047        50.0    male
#
#        anatom_site_general  clin_size_long_diam_mm          image_type  \
# 0          lower extremity                    3.04  TBP tile: close-up
# 1                head/neck                    1.10  TBP tile: close-up
# 2          posterior torso                    3.40  TBP tile: close-up
# 3           anterior torso                    3.22  TBP tile: close-up
# 4           anterior torso                    2.73  TBP tile: close-up
# ...                    ...                     ...                 ...
# 401054      anterior torso                    6.80  TBP tile: close-up
# 401055     posterior torso                    3.11  TBP tile: close-up
# 401056      anterior torso                    2.05  TBP tile: close-up
# 401057      anterior torso                    2.80  TBP tile: close-up
# 401058     lower extremity                    3.30  TBP tile: close-up
#
#        tbp_tile_type   tbp_lv_A  tbp_lv_Aext   tbp_lv_B  tbp_lv_Bext  \
# 0          3D: white  20.244422    16.261975  26.922447    23.954773
# 1          3D: white  31.712570    25.364740  26.331000    24.549290
# 2             3D: XP  22.575830    17.128170  37.970460    33.485410
# 3             3D: XP  14.242329    12.164757  21.448144    21.121356
# 4          3D: white  24.725520    20.057470  26.464900    25.710460
# ...              ...        ...          ...        ...          ...
# 401054        3D: XP  22.574335    14.944666  27.663259    26.767135
# 401055     3D: white  19.977640    16.026870  34.158840    31.011870
# 401056        3D: XP  17.332567    12.364397  29.845326    26.500073
# 401057        3D: XP  22.288570     9.564721  28.431200    27.012250
# 401058        3D: XP  16.792900    11.434730  21.457220    21.214910
#
#          tbp_lv_C  tbp_lv_Cext   tbp_lv_H  tbp_lv_Hext   tbp_lv_L  \
# 0       33.684638    28.953117  53.058545    55.828924  54.367448
# 1       41.219030    35.299260  39.702910    44.064040  48.861520
# 2       44.174920    37.611800  59.265850    62.909730  53.961180
# 3       25.746200    24.374023  56.414429    60.060388  18.649518
# 4       36.217980    32.608740  46.946070    52.041180  46.276310
# ...           ...          ...        ...          ...        ...
# 401054  35.705132    30.656525  50.784168    60.824438  36.333547
# 401055  39.571870    34.908400  59.678970    62.670170  59.102310
bp_lv_perimeterMM  tbp_lv_radial_color_std_max  tbp_lv_stdL  \
# 0                 9.307003                     0.000000     2.036195
# 1                 3.354148                     0.000000     0.853227
# 2                 8.886309                     0.000000     1.743651
# 3                 9.514499                     0.664690     1.258541
# 4                 6.467562                     0.000000     2.085409
# ...                    ...                          ...          ...
# 401054           20.210836                     2.328066     7.054819
# 401055            9.340242                     1.048147     1.879502
# 401056            5.999862                     0.607554     1.702824
# 401057            9.113276                     1.078204     3.680175
# 401058           10.128920                     1.088073     3.068755
#
#         tbp_lv_stdLExt  tbp_lv_symm_2axis  tbp_lv_symm_2axis_angle  \
# 0             2.637780           0.590476                       85
# 1             3.912844           0.285714                       55
# 2             1.950777           0.361905                      105
# 3             1.573733           0.209581                      130
# 4             2.480509           0.313433                       20
# ...                ...                ...                      ...
# 401054        2.169398           0.288920                      100
# 401055        2.910780           0.460000                       25
# 401056        2.205272           0.183099                       40
# 401057        1.957157           0.161850                      140
# 401058        3.199104           0.197917                       45
#
#           tbp_lv_x     tbp_lv_y    tbp_lv_z  \
# 0      -182.703552   613.493652  -42.427948
# 1        -0.078308  1575.687000   57.174500
# 2       123.649700  1472.010000  232.908900
# 3      -141.024780  1442.185791   58.359802
# 4       -72.315640  1488.720000   21.428960
# ...            ...          ...         ...
# 401054  147.187256  1182.317505  122.652588
# 401055   52.349740  1393.187000  127.261700
# 401056   54.622246  1065.263672 -106.833740
# 401057   -9.861557   877.527000  -76.982120
# 401058 -258.872300   148.606200  107.710600
#
#                                               attribution copyright_license  \
# 0                  Memorial Sloan Kettering Cancer Center             CC-BY
# 1                  Memorial Sloan Kettering Cancer Center             CC-BY
# 2                  Memorial Sloan Kettering Cancer Center             CC-BY
# 3                                              ACEMID MIA              CC-0
# 4                  Memorial Sloan Kettering Cancer Center             CC-BY
# ...                                                   ...               ...
# 401054  Department of Dermatology, Hospital Clínic de ...          CC-BY-NC
# 401055             Memorial Sloan Kettering Cancer Center             CC-BY
# 401056  Frazer Institute, The University of Queensland...             CC-BY
# 401057                       University Hospital of Basel          CC-BY-NC
# 401058  Department of Dermatology, University of Athen...             CC-BY
#
#          lesion_id iddx_full  iddx_1 iddx_2 iddx_3 iddx_4 iddx_5  \
# 0              NaN    Benign  Benign    NaN    NaN    NaN    NaN
# 1       IL_6727506    Benign  Benign    NaN    NaN    NaN    NaN
# 2              NaN    Benign  Benign    NaN    NaN    NaN    NaN
# 3              NaN    Benign  Benign    NaN    NaN    NaN    NaN
# 4              NaN    Benign  Benign    NaN    NaN    NaN    NaN
# ...            ...       ...     ...    ...    ...    ...    ...
# 401054  IL_9520694    Benign  Benign    NaN    NaN    NaN    NaN
# 401055         NaN    Benign  Benign    NaN    NaN    NaN    NaN
# 401056  IL_9852274    Benign  Benign    NaN    NaN    NaN    NaN
# 401057         NaN    Benign  Benign    NaN    NaN    NaN    NaN
# 401058         NaN    Benign  Benign    NaN    NaN    NaN    NaN
#
#        mel_mitotic_index  mel_thick_mm  tbp_lv_dnn_lesion_confidence
# 0                    NaN           NaN                     97.517282
# 1                    NaN           NaN                      3.141455
# 2                    NaN           NaN                     99.804040
# 3                    NaN           NaN                     99.989998
# 4                    NaN           NaN                     70.442510
# ...                  ...           ...                           ...
# 401054               NaN           NaN                     99.999988
# 401055               NaN           NaN                     99.999820
# 401056               NaN           NaN                     99.999416
# 401057               NaN           NaN                    100.000000
# 401058               NaN           NaN                     99.999960
#
# [401059 rows x 55 columns]

# %%
list(train_metadata_df.columns)
# Out:
# ['isic_id',
#  'target',
#  'patient_id',
#  'age_approx',
#  'sex',
#  'anatom_site_general',
#  'clin_size_long_diam_mm',
#  'image_type',
#  'tbp_tile_type',
#  'tbp_lv_A',
#  'tbp_lv_Aext',
#  'tbp_lv_B',
#  'tbp_lv_Bext',
#  'tbp_lv_C',
#  'tbp_lv_Cext',
#  'tbp_lv_H',
#  'tbp_lv_Hext',
#  'tbp_lv_L',
#  'tbp_lv_Lext',
#  'tbp_lv_areaMM2',
#  'tbp_lv_area_perim_ratio',
#  'tbp_lv_color_std_mean',
#  'tbp_lv_deltaA',
#  'tbp_lv_deltaB',
#  'tbp_lv_deltaL',
#  'tbp_lv_deltaLB',
#  'tbp_lv_deltaLBnorm',
#  'tbp_lv_eccentricity',
#  'tbp_lv_location',
#  'tbp_lv_location_simple',
#  'tbp_lv_minorAxisMM',
#  'tbp_lv_nevi_confidence',
#  'tbp_lv_norm_border',
#  'tbp_lv_norm_color',
#  'tbp_lv_perimeterMM',
#  'tbp_lv_radial_color_std_max',
#  'tbp_lv_stdL',
#  'tbp_lv_stdLExt',
#  'tbp_lv_symm_2axis',
#  'tbp_lv_symm_2axis_angle',
#  'tbp_lv_x',
#  'tbp_lv_y',
#  'tbp_lv_z',
#  'attribution',
#  'copyright_license',
#  'lesion_id',
#  'iddx_full',
#  'iddx_1',
#  'iddx_2',
#  'iddx_3',
#  'iddx_4',
#  'iddx_5',
#  'mel_mitotic_index',
#  'mel_thick_mm',
#  'tbp_lv_dnn_lesion_confidence']

# %%
train_metadata_df["patient_id"].value_counts()
# Out:
# patient_id
# IP_1117889    9184
# IP_5714646    6267
# IP_3921915    5568
# IP_7797815    4454
# IP_9577633    3583
#               ...
# IP_5792391       1
# IP_1216329       1
# IP_4004571       1
# IP_1487179       1
# IP_7696347       1
# Name: count, Length: 1042, dtype: int64

# %%
train_metadata_df["target"].value_counts()
# Out:
# target
# 0    400666
# 1       393
# Name: count, dtype: int64

# %%
test_metadata_df = pd.read_csv(DATA_PATH / "test-metadata.csv")
test_metadata_df
# Out:
#         isic_id  patient_id  age_approx     sex anatom_site_general  \
# 0  ISIC_0015657  IP_6074337        45.0    male     posterior torso
# 1  ISIC_0015729  IP_1664139        35.0  female     lower extremity
# 2  ISIC_0015740  IP_7142616        65.0    male     posterior torso
#
#    clin_size_long_diam_mm          image_type tbp_tile_type  tbp_lv_A  \
# 0                    2.70  TBP tile: close-up        3D: XP  22.80433
# 1                    2.52  TBP tile: close-up        3D: XP  16.64867
# 2                    3.16  TBP tile: close-up        3D: XP  24.25384
#
#    tbp_lv_Aext  tbp_lv_B  tbp_lv_Bext   tbp_lv_C  tbp_lv_Cext   tbp_lv_H  \
# 0    20.007270  28.38412    27.043640  36.410100    33.640000  51.220960
# 1     9.657964  31.31752    27.524318  35.467806    29.169579  62.004494
# 2    19.937380  30.46368    28.384240  38.939500    34.686660  51.474730
#
#    tbp_lv_Hext  tbp_lv_L  tbp_lv_Lext  tbp_lv_areaMM2  \
# 0    53.505430  24.97985    31.114600        3.846876
# 1    70.664619  59.90409    68.141071        2.120473
# 2    54.915410  35.81945    41.358640        3.396510
#
#    tbp_lv_area_perim_ratio  tbp_lv_color_std_mean  tbp_lv_deltaA  \
# 0                22.907010               0.461149       2.797056
# 1                18.957821               0.000000       6.990705
# 2                19.464400               0.251236       4.316465
#
#    tbp_lv_deltaB  tbp_lv_deltaL  tbp_lv_deltaLB  tbp_lv_deltaLBnorm  \
# 0       1.340481      -6.134747        6.436557            6.843057
# 1       3.793202      -8.236981        9.151127            6.083388
# 2       2.079433      -5.539191        6.041092            5.446997
#
#    tbp_lv_eccentricity       tbp_lv_location tbp_lv_location_simple  \
# 0             0.664465  Torso Back Top Third             Torso Back
# 1             0.926698      Left Leg - Upper               Left Leg
# 2             0.894776  Torso Back Top Third             Torso Back
#
#    tbp_lv_minorAxisMM  tbp_lv_nevi_confidence  tbp_lv_norm_border  \
# 0            2.187644            1.698104e-02            5.435366
# 1            1.032666            2.107364e-01            4.322201
# 2            1.520786            8.052259e-13            3.968912
#
#    tbp_lv_norm_color  tbp_lv_perimeterMM  tbp_lv_radial_color_std_max  \
# 0           1.143374            9.387248                     0.304827
# 1           0.000000            6.340311                     0.000000
# 2           0.721739            8.130868                     0.230742
#
#    tbp_lv_stdL  tbp_lv_stdLExt  tbp_lv_symm_2axis  tbp_lv_symm_2axis_angle  \
# 0     1.281532        2.299935           0.479339                       20
# 1     1.271940        2.011223           0.426230                       25
# 2     1.080308        2.705857           0.366071                      110
#
#     tbp_lv_x     tbp_lv_y    tbp_lv_z  \
# 0 -155.06510  1511.222000  113.980100
# 1 -112.36924   629.535889  -15.019287
# 2  -84.29282  1303.978000  -28.576050
#
#                                          attribution copyright_license
# 0             Memorial Sloan Kettering Cancer Center             CC-BY
# 1  Frazer Institute, The University of Queensland...             CC-BY
# 2                                        FNQH Cairns             CC-BY

# %%
[col for col in train_metadata_df.columns if col not in test_metadata_df.columns]
# Out:
# ['target',
#  'lesion_id',
#  'iddx_full',
#  'iddx_1',
#  'iddx_2',
#  'iddx_3',
#  'iddx_4',
#  'iddx_5',
#  'mel_mitotic_index',
#  'mel_thick_mm',
#  'tbp_lv_dnn_lesion_confidence']

# %%
sample_submission_df = pd.read_csv(DATA_PATH / "sample_submission.csv")
sample_submission_df
# Out:
#         isic_id  target
# 0  ISIC_0015657     0.3
# 1  ISIC_0015729     0.3
# 2  ISIC_0015740     0.3

# %%
train_imgs_filenames = os.listdir(DATA_PATH / "train-image/image")
print(train_imgs_filenames[:5])
print("len imgs: ", len(train_imgs_filenames))
# Out:
# ['ISIC_0015670.jpg', 'ISIC_0015845.jpg', 'ISIC_0015864.jpg', 'ISIC_0015902.jpg', 'ISIC_0024200.jpg']
# len imgs:  401059

# %%
pos_img_files = random.sample(list(train_metadata_df
